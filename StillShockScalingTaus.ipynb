# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import glob
import os

# %%
# %matplotlib inline

# %% [markdown]
# # 1d case

# %%
# How many? -1 == all
resses = -1
sizes = [100, 200, 400]#, 800, 1600, 3200]
sizes = sizes[0:resses]

fs_ID_100 = []
fs_ID_200 = []
fs_ID_400 = []
fs_ID_800 = []
fs_ID_1600 = []
fs_ID_3200 = []

fs_IS_100 = []
fs_IS_200 = []
fs_IS_400 = []
fs_IS_800 = []
fs_IS_1600 = []
fs_IS_3200 = []

fs_ISCE_100 = []
fs_ISCE_200 = []
fs_ISCE_400 = []
fs_ISCE_800 = []
fs_ISCE_1600 = []
fs_ISCE_3200 = []

for n in range(51):
    fs_IS_100.append(h5py.File(f'IS/StillShock/all/tau_scaling/0.001000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_100.append(h5py.File(f'ISCE/StillShock/all/str_scal/0.000100/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_100.append(h5py.File(f'IS/StillShock/Ideal/scaling/100/data_serial_TIx_{n}.hdf5', 'r'))
    
    fs_IS_200.append(h5py.File(f'IS/StillShock/all/tau_scaling/0.010000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_200.append(h5py.File(f'ISCE/StillShock/all/str_scal/0.000100/data_serial_TIx_{n}.hdf5', 'r'))  
#     fs_ID_200.append(h5py.File(f'IS/StillShock/Ideal/scaling/200/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_400.append(h5py.File(f'IS/StillShock/all/tau_scaling/0.100000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_400.append(h5py.File(f'ISCE/StillShock/all/str_scal/0.000100/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_400.append(h5py.File(f'IS/StillShock/Ideal/scaling/400/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_800.append(h5py.File(f'IS/StillShock/all/tau_scaling/1.000000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_800.append(h5py.File(f'ISCE/StillShock/all/str_scal/0.000100/data_serial_TIx_{n}.hdf5', 'r'))    
#     fs_ID_800.append(h5py.File(f'IS/StillShock/Ideal/scaling/800/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_1600.append(h5py.File(f'IS/StillShock/all/tau_scaling/10.000000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_1600.append(h5py.File(f'ISCE/StillShock/all/str_scal/0.000100/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_1600.append(h5py.File(f'IS/StillShock/Ideal/scaling/1600/data_serial_TIx_{n}.hdf5', 'r'))

    #fs_IS_3200.append(h5py.File(f'IS/StillShock/all/tau_scaling/3200/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ISCE_3200.append(h5py.File(f'ISCE/StillShock/all/str_scaling/3200/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_3200.append(h5py.File(f'IS/StillShock/Ideal/scaling/3200/data_serial_TIx_{n}.hdf5', 'r'))
    
# for p in range(len(fss_IS)-1):
#     for n in range(6):
#         fss_IS[p+1] = h5py.File(f'IS/StillShock/Shear/tau_scaling/'+str(100*2**p)+f'/data_serial_TIx_{n}.hdf5', 'r')
#         fss_ISCE[p+1] = h5py.File(f'ISCE/StillShock/Shear/tau_scaling/'+str(100*2**p)+f'/data_serial_TIx_{n}.hdf5', 'r')
   
fss_IS = [fs_IS_100, fs_IS_200, fs_IS_400, fs_IS_800, fs_IS_1600]#, fs_IS_3200]
#fss_IS = fss_IS[0:resses]

fss_ISCE = [fs_ISCE_1600, fs_ISCE_1600, fs_ISCE_1600, fs_ISCE_1600, fs_ISCE_1600]#, fs_ISCE_1600]
#fss_ISCE = fss_ISCE[0:resses]

#fss_ID = [fs_ID_100, fs_ID_200, fs_ID_400, fs_ID_800, fs_ID_1600, fs_ID_3200]
#fss_ID = fss_ID[0:resses]

fss = [fss_IS, fss_ISCE]#, fss_ISCE]

# %%
fss_IS
# Out:
# [[<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>]]

# %%
fssIS, fssISCE = fss[0], fss[1]
for fsIS, fsISCE in zip(fssIS, fssISCE):
    print(fsIS[0]['Primitive/pi11'].shape)
    print(fsISCE[0]['Primitive/p'].shape)
# Out:
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)

# %%
print("IS, zeta: \n")
for fs in fss[0]:
    zeta = fs[0]['Optional'].attrs['zeta'][0]
    tau_Pi = fs[0]['Optional'].attrs['tau_Pi'][0]
    print(f"Dissipation strength {zeta}, "
          f"relaxation time {tau_Pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
print("ISCE, zeta: \n")
for fs in fss[1]:
    zeta = fs[0]['Optional'].attrs['zeta'][0]
    tau_Pi = fs[0]['Optional'].attrs['tau_Pi'][0]
    print(f"Dissipation strength {zeta}, "
          f"relaxation time {tau_Pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
# Out:
# IS, zeta:
#
# Dissipation strength 0.01, relaxation time 0.0010000000474974513, timestep 5e-05
# Dissipation strength 0.01, relaxation time 0.009999999776482582, timestep 5e-05
# Dissipation strength 0.01, relaxation time 0.10000000149011612, timestep 5e-05
# Dissipation strength 0.01, relaxation time 1.0, timestep 5e-05
# Dissipation strength 0.01, relaxation time 10.0, timestep 5e-05
# ISCE, zeta:
#
# Dissipation strength 0.009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.009999999747378752, relaxation time 0.1, timestep 5e-05

# %%
print("IS, kappa: \n")
for fs in fss[0]:
    kappa = fs[0]['Optional'].attrs['kappa'][0]
    tau_q = fs[0]['Optional'].attrs['tau_q'][0]
    print(f"Dissipation strength {kappa}, "
          f"relaxation time {tau_q}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
print("ISCE, kappa: \n")
for fs in fss[1]:
    kappa = fs[0]['Optional'].attrs['kappa'][0]
    tau_q = fs[0]['Optional'].attrs['tau_q'][0]
    print(f"Dissipation strength {kappa}, "
          f"relaxation time {tau_q}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
# Out:
# IS, kappa:
#
# Dissipation strength 0.0001, relaxation time 0.0010000000474974513, timestep 5e-05
# Dissipation strength 0.0001, relaxation time 0.009999999776482582, timestep 5e-05
# Dissipation strength 0.0001, relaxation time 0.10000000149011612, timestep 5e-05
# Dissipation strength 0.0001, relaxation time 1.0, timestep 5e-05
# Dissipation strength 0.0001, relaxation time 10.0, timestep 5e-05
# ISCE, kappa:
#
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 5e-05
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 5e-05
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 5e-05
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 5e-05
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 5e-05

# %%
taus = []
print("IS, eta: \n")
for fs in fss[0]:
    eta = fs[0]['Optional'].attrs['eta'][0]
    tau_pi = fs[0]['Optional'].attrs['tau_pi'][0]
    print(f"Dissipation strength {eta}, "
          f"relaxation time {tau_pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
    taus.append(tau_pi)
print("ISCE, eta: \n")
for fs in fss[1]:
    eta = fs[0]['Optional'].attrs['eta'][0]
    tau_pi = fs[0]['Optional'].attrs['tau_pi'][0]
    print(f"Dissipation strength {eta}, "
          f"relaxation time {tau_pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
# Out:
# IS, eta:
#
# Dissipation strength 0.001, relaxation time 0.0010000000474974513, timestep 5e-05
# Dissipation strength 0.001, relaxation time 0.009999999776482582, timestep 5e-05
# Dissipation strength 0.001, relaxation time 0.10000000149011612, timestep 5e-05
# Dissipation strength 0.001, relaxation time 1.0, timestep 5e-05
# Dissipation strength 0.001, relaxation time 10.0, timestep 5e-05
# ISCE, eta:
#
# Dissipation strength 0.0009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.0009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.0009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.0009999999747378752, relaxation time 0.1, timestep 5e-05
# Dissipation strength 0.0009999999747378752, relaxation time 0.1, timestep 5e-05

# %%
for fs in fss[0]:
    print(fs[-1].attrs['t'])
for fs in fss[1]:
    print(fs[-1].attrs['t'])
# Out:
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]
# [0.8]

# %%
#nslice=fs_IS[0]['Domain'].attrs['ny'][0]//2
  
for quant in['D','Tau','S1']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            axis.plot(fs[-1]['Domain/x'], fs[-1]['Conserved/'+quant][:])#,label=rf"$t=${f.attrs['t'][0]:.2e}")
            plt.title(quant)
        #plt.legend()
    plt.savefig("ComparePlots/Cons_"+quant+".pdf")
    plt.show()

# %%
# for quant in['D','Tau','S1']:
#     plt.figure()
#     for n in range(len(fs_IS)):
#         #plt.plot(f['Domain/x'], f['Conserved/'+quant][:,nslice,nslice],label=rf"$t=${f.attrs['t'][0]:.2e}")
#         plt.plot(fs_IS[n]['Domain/x'], (fs_IS[n]['Conserved/'+quant][:] - fs_ISCE[n]['Conserved/'+quant][:])/fs_IS[n]['Conserved/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
#         plt.title(quant)
#     plt.legend()
#     plt.savefig("ComparePlots/ConsRelDiff_"+quant+".pdf")
#     plt.show()

# %%
print("INITIAL DATA")
for quant in['n','rho','p','v1','v2']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            axis.plot(fs[0]['Domain/x'], fs[0]['Primitive/'+quant][:])#=rf"$t=${f.attrs['t'][0]:.2e}")
            plt.title(quant)
    #plt.legend()
    plt.show()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")
# Out:
# INITIAL DATA

# %%
quant_names = [r'$n$',r'$\rho$',r'$p$',r'$v_1$',r'$v_2$']
titles = ['IS','ISCE']
for quant, quant_name in zip(['n','rho','p','v1','v2'],quant_names):
    fig, axes = plt.subplots(1,2,figsize=(12,6))
    for axis, fssISISCE, titl in zip(axes, fss, titles):
        for fs, tau in zip(fssISISCE[::2], taus[::2]):
#             print(fs)
            axis.plot(fs[-1]['Domain/x'], fs[-1]['Primitive/'+quant][:], label=f'{tau:.2g}')
            axis.set_xlabel(r'$x$')
            axis.set_ylabel(quant_name)
        axis.set_title(titl)
#         plt.title(quant)
    fig.tight_layout()
    plt.legend()
#     plt.savefig("ComparePlots/Prims_ISvsISCE_all3tauscaling_"+quant+".pdf")

# %%
for quant in ['Pi','q1', 'q2', 'pi11', 'pi12']:
    fig, axes = plt.subplots(1,2)
    axis = axes[0]
    for fsIS in fss_IS:
        for fIS in fsIS:
            axis.plot(fIS['Domain/x'], fIS['Primitive/'+quant][:],label='IS')#=rf"$t=${f.attrs['t'][0]:.2e}")
    axis = axes[1]
    for fsISCE in fss_ISCE:
        for fISCE in fsISCE:
            axis.plot(fISCE['Domain/x'], fISCE['Auxiliary/'+quant+'NS'][:],label='ISCE')#=rf"$t=${f.attrs['t'][0]:.2e}")
    plt.title(quant+' , '+quant+'NS')
    #plt.legend()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")

# %%
lims = [0,1]
plt.figure()
for quant in['n','rho','p','v1','v2']:
    for fsIS, fsISCE in zip(fss_IS, fss_ISCE):
        nsl = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
        nsu = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
        plt.plot(fsIS[0]['Domain/x'][nsl:nsu], fsIS[-1]['Primitive/'+quant][nsl:nsu] - fsISCE[-1]['Primitive/'+quant][nsl:nsu])
        #plt.plot(fsIS[0]['Domain/x'], fsIS[1]['Primitive/'+quant][:] - fsISCE[1]['Primitive/'+quant][:])
        plt.title(quant)
    plt.savefig("ComparePlots/DiffAcrossDomain_"+quant+".pdf")
    plt.show()

# %%
lims = [0,1]
plt.figure()
for quant in['n','rho','p','v1','v2']:
    for fsIS in fss_IS:
        nsl = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
        nsu = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
        tau_pi = fsIS[0]['Optional'].attrs['tau_pi'][0]
        plt.plot(fsIS[0]['Domain/x'][nsl:nsu], fsIS[1]['Primitive/'+quant][nsl:nsu],
                 label=f'{tau_pi:.1g}')
        #plt.plot(fsIS[0]['Domain/x'], fsIS[1]['Primitive/'+quant][:] - fsISCE[1]['Primitive/'+quant][:])
    plt.legend()
    plt.title(quant)
    plt.savefig("ComparePlots/DiffAcrossDomain_"+quant+".pdf")
    plt.show()

# %%
a = [3,4,5]
b = [3,4,5,3,4,5]
print(np.linalg.norm(a,np.inf))
print(np.linalg.norm(b,np.inf))
# Out:
# 5.0
# 5.0

# %%
diffs = []
plt.figure()
for quant in['n','rho','p','v1','v2']:
    for fsIS, fsISCE, size in zip(fss_IS, fss_ISCE, sizes):
        nslice_lower = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
        nslice_upper = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
#         diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
#                                    - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),1)/size))
        diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
                                   - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),2)))
#         diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
#                                    - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),np.inf)))
    plt.plot(sizes, diffs)
    slope, intercept = np.polyfit(sizes, diffs, 1)
    print(slope, intercept)
    #plt.plot(sizes, intercept + slope*np.array(sizes))
    #plt.plot(sizes, diffs)
    plt.title(quant)
    plt.savefig("ComparePlots/DiffScaling_"+quant+".pdf")
    plt.show()
    diffs.clear()

# for quant in['n','rho','p','v1','v2']:
#     for fsIS, fsISCE, size in zip(fss_IS, fss_ISCE, sizes):
#         print(size, np.sum(np.abs(fsIS[-1]['Primitive/'+quant][:] - fsISCE[-1]['Primitive/'+quant][:])))
#         plt.plot(size, np.sum(np.abs(fsIS[-1]['Primitive/'+quant][:] - fsISCE[-1]['Primitive/'+quant][:])))
#     plt.title(quant)
#     plt.show()
#     #plt.legend()
#     plt.savefig("ComparePlots/Prims_"+quant+".pdf")
# Out:
# 0.0012293787398034827 5.406439558352152
# 0.0017323261624296877 21.599514544046528
# 6.191631443996694e-05 11.276745076440662
# 0.0015367952334014755 2.0404791142236474
# -4.151593256549521e-06 0.0032693963077759787

# %%
for quant in['n','rho','p','v1','v2']:
    plt.figure()
    #for f in fs:
    fIS = fs_IS[-1]
    fISCE = fs_ISCE[-1]
    plt.plot(fIS['Domain/x'], (fIS['Primitive/'+quant][:] - fISCE['Primitive/'+quant][:])/fIS['Primitive/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
    plt.title(quant)
    plt.legend()
    plt.savefig("ComparePlots/PrimsRelDiff_"+quant+".pdf")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9eb475c46301> in <module>
#       2     plt.figure()
#       3     #for f in fs:
# ----> 4     fIS = fs_IS[-1]
#       5     fISCE = fs_ISCE[-1]
#       6     plt.plot(fIS['Domain/x'], (fIS['Primitive/'+quant][:] - fISCE['Primitive/'+quant][:])/fIS['Primitive/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
#
# NameError: name 'fs_IS' is not defined

# %%
# for quant in['Pi','q1', 'q2', 'pi11', 'pi12']:
#     plt.figure()
#     #for f in fs:
#     fIS = fs_IS[-1]
#     fISCE = fs_ISCE[-1]
#     plt.plot(fIS['Domain/x'], (fIS['Primitive/'+quant][:] - fISCE['Auxiliary/'+quant+'NS'][:])/fIS['Primitive/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
#     plt.title(quant+' - '+quant+'NS / '+quant)
#     plt.legend()
#     plt.savefig("ComparePlots/PrimsDiff_"+quant+".pdf")
#     plt.show()

# %%
for quant in['v1', 'Pi','q1', 'q2', 'pi11', 'pi12']:
    for fsIS in fss_IS:
        tau_pi = fsIS[0]['Optional'].attrs['tau_pi'][0]
        plt.plot(fsIS[0]['Domain/x'][:], fsIS[1]['Primitive/'+quant][:],
                 label=f'{tau_pi:.1g}')
    plt.legend()
    plt.title(quant)
    plt.savefig("ComparePlots/DiffAcrossDomain_"+quant+".pdf")
    plt.show()

# %%
for quant in ['T','a1']:
    plt.figure()
    for f in fs_IS:
        #plt.plot(f['Domain/x'], f['Auxiliary/'+quant][:,nslice,nslice],label=rf"$t=${f.attrs['t'][0]:.2e}")
        plt.plot(f['Domain/x'], f['Auxiliary/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
    for f in fs_ISCE:
        #plt.plot(f['Domain/x'], f['Auxiliary/'+quant][:,nslice,nslice],label=rf"$t=${f.attrs['t'][0]:.2e}")
        plt.plot(f['Domain/x'], f['Auxiliary/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
    plt.title(quant)
    plt.legend()
    plt.savefig("ComparePlots/Aux_"+quant+".pdf")
    plt.show()
