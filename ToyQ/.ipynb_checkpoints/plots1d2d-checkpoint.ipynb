# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import glob
import os

# %%
# %matplotlib inline

# %% [markdown]
# # 1d case

# %%
fs_imex = []
files = sorted(glob.glob('Blob/1d/data*1em4*hdf5'), key=os.path.getmtime)
for f in files:
    fs_imex.append(h5py.File(f, 'r'))

# %%
fs_ce = []
files = sorted(glob.glob('BlobCE/1d/data*1em4*hdf5'), key=os.path.getmtime)
for f in files:
    fs_ce.append(h5py.File(f, 'r'))

# %%
plt.plot(fs_ce[0]['Primitive/T'][:])
plt.plot(fs_ce[-1]['Primitive/T'][:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-2c9ab0e81fe6> in <module>
# ----> 1 plt.plot(fs_ce[0]['Primitive/T'][:])
#       2 plt.plot(fs_ce[-1]['Primitive/T'][:])
#
# IndexError: list index out of range

# %%
plt.plot(fs_imex[0]['Primitive/T'][:])
plt.plot(fs_imex[-1]['Primitive/T'][:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-a96cc795ffea> in <module>
# ----> 1 plt.plot(fs_imex[0]['Primitive/T'][:])
#       2 plt.plot(fs_imex[-1]['Primitive/T'][:])
#
# IndexError: list index out of range

# %%
print("kappa the same?", np.allclose(fs_imex[0]['Optional'].attrs['kappa'], fs_ce[0]['Optional'].attrs['kappa']))
print("tau_q the same?", np.allclose(fs_imex[0]['Optional'].attrs['tau_q'], fs_ce[0]['Optional'].attrs['tau_q']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-c086599dfa85> in <module>
# ----> 1 print("kappa the same?", np.allclose(fs_imex[0]['Optional'].attrs['kappa'], fs_ce[0]['Optional'].attrs['kappa']))
#       2 print("tau_q the same?", np.allclose(fs_imex[0]['Optional'].attrs['tau_q'], fs_ce[0]['Optional'].attrs['tau_q']))
#
# IndexError: list index out of range

# %%
fig, axes = plt.subplots(6, 2, figsize=(8, 20))
for axi, i in enumerate(range(0, len(fs_imex), len(fs_imex)//5)):
    axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:], label='IMEX')
    axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_ce[i]['Primitive/T'][:], label='CE')
    axes[axi, 0].legend()
    axes[axi, 0].set_title(f"Time = {fs_imex[i].attrs['t'][0]:.2f}")
    axes[axi, 1].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:]-fs_ce[i]['Primitive/T'][:], label='IMEX')
    axes[axi, 1].legend()
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-45f948da4936> in <module>
#       1 fig, axes = plt.subplots(6, 2, figsize=(8, 20))
# ----> 2 for axi, i in enumerate(range(0, len(fs_imex), len(fs_imex)//5)):
#       3     axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:], label='IMEX')
#       4     axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_ce[i]['Primitive/T'][:], label='CE')
#       5     axes[axi, 0].legend()
#
# ValueError: range() arg 3 must not be zero

# %%
plt.plot(fs_ce[1]['Auxiliary/del2T'])

# %%
plt.plot(fs_ce[1]['Auxiliary/del4T'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-4f968ada6bdd> in <module>
# ----> 1 plt.plot(fs_ce[1]['Auxiliary/del4T'])
#
# IndexError: list index out of range

# %% [markdown]
# # 2d case

# %%
fs_imex = []
files = sorted(glob.glob('2d/data*1em3*hdf5'))#, key=os.path.getmtime)
# for f in files:
#     fs_imex.append(h5py.File(f, 'r'))
for i in range(len(files)):
    fs_imex.append(h5py.File(f'2d\\data_1em3_serial{i}.hdf5', 'r'))
#fs_imex

# %%
fs_ce = []
files = sorted(glob.glob('2dCE/data*1em3*hdf5'), key=os.path.getmtime)
# for f in files:
#     fs_ce.append(h5py.File(f, 'r'))
for i in range(len(files)):
    fs_ce.append(h5py.File(f'2dCE\\data_1em3_serial{i}.hdf5', 'r'))
#fs_ce

# %%
nx = fs_imex[0]['Domain'].attrs['nx'][0]
ny = fs_imex[0]['Domain'].attrs['ny'][0]

# %%
fig, axes = plt.subplots(6, 2, figsize=(8, 20))
for axi, i in enumerate(range(0, len(fs_imex), len(fs_imex)//5)):
    axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:, ny//2], label='IMEX')
    axes[axi, 0].plot(fs_imex[i]['Domain/x'], fs_ce[i]['Primitive/T'][:, ny//2], label='CE')
    axes[axi, 0].legend()
    axes[axi, 0].set_title(f"Time = {fs_imex[i].attrs['t'][0]:.2f}")
    axes[axi, 1].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:, ny//2]-fs_ce[i]['Primitive/T'][:, ny//2], label='IMEX')
    axes[axi, 1].legend()
fig.tight_layout()
plt.show()

# %%
fig = plt.figure()
for i in range(len(fs_imex))[::10]:
     plt.plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:, ny//2], label='t=' + str(fs_imex[i].attrs['t'][0]))
     plt.plot(fs_imex[i]['Domain/x'], fs_ce[i]['Primitive/T'][:, ny//2], '--')
#     plt.plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:, ny//2]-fs_ce[i]['Primitive/T'][:, ny//2], label='IMEX')

#     axes[axi, 0].set_title(f"Time = {fs_imex[i].attrs['t'][0]:.2f}")
#     axes[axi, 1].plot(fs_imex[i]['Domain/x'], fs_imex[i]['Primitive/T'][:, ny//2]-fs_ce[i]['Primitive/T'][:, ny//2], label='IMEX')
#     axes[axi, 1].legend()
#plt.plot(fs_imex[0]['Domain/x'],0.85*np.sinc(3*(fs_imex[i]['Domain/x'][:]-0.5)))
fig.tight_layout()
plt.title('Dissipation of a temperature top-hat by the heat flux')
plt.xlabel(r'x')
plt.ylabel('Temperature, T')
plt.legend()
plt.show()
