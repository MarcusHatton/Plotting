# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
from matplotlib.animation import FuncAnimation, ArtistAnimation
from IPython.display import HTML

# %%
fs_IS_Id = []
fs_ISCE_Id = []
fs_BDNK_Id = []

fs_IS_Sh = []
fs_ISCE_Sh = []
fs_BDNK_Sh = []

# for n in range(11):
#   fs_IS_Id.append(h5py.File('IS/KH/Ideal/cfl04/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Id.append(h5py.File('ISCE/KH/Ideal/cfl04/dp_200x200x0_'+str(n)+'.hdf5','r'))
  
#   fs_IS_Sh.append(h5py.File('IS/KH/Shear/cfl04/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/cfl04/dp_200x200x0_'+str(n)+'.hdf5','r'))

num_outputs = 6
for n in range(num_outputs):
  fs_IS_Id.append(h5py.File('IS/KH/Ideal/dp_800x800x0_'+str(n)+'.hdf5','r'))
  fs_ISCE_Id.append(h5py.File('ISCE/KH/Ideal/dp_800x800x0_'+str(n)+'.hdf5','r'))

#   fs_IS_Id.append(h5py.File('IS/KH/Ideal/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Id.append(h5py.File('ISCE/KH/Ideal/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_BDNK_Id.append(h5py.File('BDNK/KH/Ideal/dp_200x200x0_'+str(n)+'.hdf5','r'))
    
#   fs_IS_Sh.append(h5py.File('IS/KH/Shear/TI/dp_800x800x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/TI/dp_800x800x0_'+str(n)+'.hdf5','r'))

#   fs_IS_Sh.append(h5py.File('IS/KH/Shear/dp_800x800x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/dp_800x800x0_'+str(n)+'.hdf5','r'))

#   fs_IS_Sh.append(h5py.File('IS/KH/Shear/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/dp_200x200x0_'+str(n)+'.hdf5','r'))

#   fs_IS_Sh.append(h5py.File('IS/KH/Shear/tau5em1eta5em3/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/tau5em2eta5em3/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_ISCE_Sh.append(h5py.File('ISCE/KH/Shear/tau5em3eta1em3wide/dp_200x200x0_'+str(n)+'.hdf5','r'))

#   fs_BDNK_Sh.append(h5py.File('BDNK/KH/zeta1em3/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_BDNK_Sh.append(h5py.File('BDNK/KH/eta0_1em5/dp_800x800x0_'+str(n)+'.hdf5','r'))
#   fs_BDNK_Sh.append(h5py.File('BDNK/KH/eta0_5em4/dp_200x200x0_'+str(n)+'.hdf5','r'))
#   fs_BDNK_Sh.append(h5py.File('BDNK/KH/eta0_5em4_newID/dp_200x200x0_'+str(n)+'.hdf5','r')) #HACK
#   fs_BDNK_Sh.append(h5py.File('BDNK/KH/eta0_2em4_coarse/dp_200x200x0_'+str(n)+'.hdf5','r')) #HACK
    #   fs_BDNK_Sh.append(h5py.File('BDNK/KH/eta0_2em5/dp_200x200x0_'+str(n)+'.hdf5','r'))
    
# fss = [fs_ISCE_Id, fs_BDNK_Id, fs_BDNK_Sh]
# fss = [fs_IS_Sh, fs_ISCE_Sh, fs_BDNK_Sh]
#fss = [fs_IS_Id, fs_IS_Sh]
fss = [fs_IS_Id, fs_ISCE_Id]

# %%
# fs1 = []
# fs2 = []
# fs3 = []
# for n in range(6):
#   fs1.append(h5py.File('IS/ShearTest/Ideal/data_serial_TIx_'+str(n)+'.hdf5','r'))
#   fs2.append(h5py.File('IS/ShearTest/Shear/data_serial_TIx_'+str(n)+'.hdf5','r'))
#   fs3.append(h5py.File('ISCE/ShearTest/Shear/data_serial_TIx_'+str(n)+'.hdf5','r'))
# fss = [fs1, fs2, fs3]
# fss = [fs1, fs3]

# %%
for fs in fss:
    print('kappa:'+str(fs[0]['Optional'].attrs['kappa']))
for fs in fss:
    print('zeta:'+str(fs[0]['Optional'].attrs['zeta']))
for fs in fss:
    try:
        print('eta:'+str(fs[0]['Optional'].attrs['eta']))
    except:
        print('eta_0:'+str(fs[0]['Optional'].attrs['eta_0']))        
# for fs in fss:
#     print('tau_q:'+str(fs[0]['Optional'].attrs['tau_q']))
# for fs in fss:
#     print('tau_Pi:'+str(fs[0]['Optional'].attrs['tau_Pi']))
# for fs in fss:
#     print('tau_pi:'+str(fs[0]['Optional'].attrs['tau_pi']))
for fs in fss:
    print('dt:'+str(fs[0]['Domain'].attrs['dt']))
for fs in fss:
    print('endTime:'+str(fs[-1].attrs['t']))
# Out:
# kappa:[1.e-15]
# zeta:[1.e-15]
# eta:[0.0001]
# dt:[0.00035355]
# endTime:[30.]

# %%
fs[0]['Optional'].attrs.keys()
# Out:
# <KeysViewHDF5 ['chi_0', 'eta_0', 'kappa', 'lambda_0', 'nOptionalSimArgs', 'zeta']>

# %%
print("INITIAL DATA")
for var in 'p', 'rho', 'n', 'v1', 'v2':
    for fs in fss:
        plt.imshow(fs[0]['Primitive/'+var][:,:])
        plt.colorbar()
        plt.title(var)
        plt.show()
# Out:
# INITIAL DATA

# %%
plt.figure
for fs in fss:
    plt.imshow(fs[-1]['Primitive/v1'][:,:])
    plt.colorbar()
    plt.title('v1')
    plt.show()
    #plt.legend()
plt.savefig('v1.pdf')

# %%
plt.figure
for fs in fss:
    plt.imshow(fs[-1]['Primitive/v2'][:,:])
    plt.colorbar()
    plt.title('v2')
    plt.show()
#plt.legend()
plt.savefig('v2.pdf')

# %%
def TwoDAnimation(i, VarClass, Var, num_frames):
    fs = fss[i]
    fig, ax = plt.subplots()
    images = []
    for frame_num in range(num_frames):
        image = plt.imshow(fs[frame_num][VarClass+'/'+Var][:,:])
        if frame_num == 0:
            plt.colorbar()
#         images.append([plt.imshow(fs[frame_num][VarClass+'/'+Var][:,:])])
        images.append([image])

    anim = ArtistAnimation(fig, images, blit=True, repeat_delay=0, interval=500)
    return anim

# %%
def TwoDAnimationDiff(i, j, VarClass, Var, num_frames):
    fs1 = fss[i]
    fs2 = fss[j]
    fig, ax = plt.subplots()
    images = []
    for frame_num in range(num_frames):
        images.append([plt.imshow((fs1[frame_num][VarClass+'/'+Var][:,:] - fs2[frame_num][VarClass+'/'+Var][:,:])/fs1[frame_num][VarClass+'/'+Var][:,:])])

    anim = ArtistAnimation(fig, images, blit=True, repeat_delay=0, interval=500)
    plt.colorbar()
    plt.clim(0,1)
    return anim

# %%
# anim = TwoDAnimationDiff(0, 1, 'Primitive','v1',31)
# HTML(anim.to_jshtml())

# %%
# anim = TwoDAnimation(0, 'Primitive','v1',11)
anim = TwoDAnimation(0, 'Primitive','n',num_outputs)
HTML(anim.to_jshtml())
# anim.save('ISKHeta1em4.gif')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-f0e89951c0e0> in <module>
#       1 # anim = TwoDAnimation(0, 'Primitive','v1',11)
# ----> 2 anim = TwoDAnimation(0, 'Primitive','n',num_outputs)
#       3 HTML(anim.to_jshtml())
#       4 # anim.save('ISKHeta1em4.gif')
#
# <ipython-input-29-44b14efd7d32> in TwoDAnimation(i, VarClass, Var, num_frames)
#       4     images = []
#       5     for frame_num in range(num_frames):
# ----> 6         image = plt.imshow(fs[frame_num][VarClass+'/'+Var][:,:])
#       7         if frame_num == 0:
#       8             plt.colorbar()
#
# IndexError: list index out of range

# %%
for var in 'D', 'S1', 'S2', 'Tau':
    for fs in fss:
        plt.imshow(fs[-1]['Conserved/'+var][:])
        plt.title(var)
        #plt.legend()
        plt.savefig(var+'.pdf')
        plt.show()

# %%
for var in 'p', 'rho', 'n':
    for fs in fss:
        plt.imshow(fs[-1]['Primitive/'+var][:])
        plt.title(var)
        plt.colorbar()
        plt.savefig(var+'.pdf')
        plt.show()

# %%
anim = TwoDAnimation(0, 'Primitive','v1',31)
# anim = TwoDAnimationDiff(0, 1, 'Primitive','n',11)
HTML(anim.to_jshtml())
# anim.save('BDNK_KH.gif')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
for var in 'q1', 'q2', 'Pi', 'pi11', 'pi12', 'pi22':
    for fs in fss:
        plt.imshow(fs[-1]['Primtive/'+var][:],label=var)
        plt.title(var)
        plt.colorbar()
        #plt.legend()
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-28556ebb12c0> in <module>
#       1 for var in 'q1', 'q2', 'Pi', 'pi11', 'pi12', 'pi22':
#       2     for fs in fss:
# ----> 3         plt.imshow(fs[-1]['Primtive/'+var][:],label=var)
#       4         plt.title(var)
#       5         plt.colorbar()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...
