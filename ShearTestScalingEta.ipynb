# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import glob
import os

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # 1d case

# %%
# How many? -1 == all
resses = -1
etas = [1e-4, 1e-3, 1e-2, 5e-2]
#sizes = sizes[0:resses]

fs_ID_100 = []
fs_ID_200 = []
fs_ID_400 = []
fs_ID_800 = []
fs_ID_1600 = []
fs_ID_3200 = []

fs_IS_100 = []
fs_IS_200 = []
fs_IS_400 = []
fs_IS_800 = []
fs_IS_1600 = []
fs_IS_3200 = []

fs_ISCE_100 = []
fs_ISCE_200 = []
fs_ISCE_400 = []
fs_ISCE_800 = []
fs_ISCE_1600 = []
fs_ISCE_3200 = []

for n in range(51):
#     fs_IS_100.append(h5py.File(f'IS/PureShear/Shear/etas/0.000010/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ISCE_100.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.000010/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_100.append(h5py.File(f'IS/PureShear/Ideal/scaling/100/data_serial_TIx_{n}.hdf5', 'r'))
    
    fs_IS_200.append(h5py.File(f'IS/PureShear/Shear/etas/0.000100/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_200.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.000100/data_serial_TIx_{n}.hdf5', 'r'))  
#     fs_ID_200.append(h5py.File(f'IS/PureShear/Ideal/scaling/200/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_400.append(h5py.File(f'IS/PureShear/Shear/etas/0.001000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_400.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.001000/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_400.append(h5py.File(f'IS/PureShear/Ideal/scaling/400/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_800.append(h5py.File(f'IS/PureShear/Shear/etas/0.010000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_800.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.010000/data_serial_TIx_{n}.hdf5', 'r'))    
#     fs_ID_800.append(h5py.File(f'IS/PureShear/Ideal/scaling/800/data_serial_TIx_{n}.hdf5', 'r'))

    fs_IS_1600.append(h5py.File(f'IS/PureShear/Shear/etas/0.050000/data_serial_TIx_{n}.hdf5', 'r'))
    fs_ISCE_1600.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.050000/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_1600.append(h5py.File(f'IS/PureShear/Ideal/scaling/1600/data_serial_TIx_{n}.hdf5', 'r'))

#     fs_IS_3200.append(h5py.File(f'IS/PureShear/Shear/etas/0.100000/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ISCE_3200.append(h5py.File(f'ISCE/PureShear/Shear/etas/0.100000/data_serial_TIx_{n}.hdf5', 'r'))
#     fs_ID_3200.append(h5py.File(f'IS/PureShear/Ideal/scaling/3200/data_serial_TIx_{n}.hdf5', 'r'))
    
# for p in range(len(fss_IS)-1):
#     for n in range(6):
#         fss_IS[p+1] = h5py.File(f'IS/PureShear/Shear/tau_scaling/'+str(100*2**p)+f'/data_serial_TIx_{n}.hdf5', 'r')
#         fss_ISCE[p+1] = h5py.File(f'ISCE/PureShear/Shear/tau_scaling/'+str(100*2**p)+f'/data_serial_TIx_{n}.hdf5', 'r')
   
fss_IS = [fs_IS_200, fs_IS_400, fs_IS_800, fs_IS_1600]#, fs_IS_3200]
#fss_IS = fss_IS[0:resses]

fss_ISCE = [fs_ISCE_200, fs_ISCE_400, fs_ISCE_800, fs_ISCE_1600]#, fs_IS_3200]
#fss_ISCE = fss_ISCE[0:resses]

#fss_ID = [fs_ID_100, fs_ID_200, fs_ID_400, fs_ID_800, fs_ID_1600, fs_ID_3200]
#fss_ID = fss_ID[0:resses]

fss = [fss_IS, fss_ISCE]#, fss_ISCE]

# %%
fss_IS
# Out:
# [[<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>],
#  [<HDF5 file "data_serial_TIx_0.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_1.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_2.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_3.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_4.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_5.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_6.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_7.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_8.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_9.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_10.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_11.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_12.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_13.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_14.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_15.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_16.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_17.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_18.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_19.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_20.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_21.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_22.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_23.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_24.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_25.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_26.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_27.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_28.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_29.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_30.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_31.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_32.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_33.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_34.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_35.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_36.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_37.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_38.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_39.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_40.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_41.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_42.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_43.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_44.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_45.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_46.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_47.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_48.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_49.hdf5" (mode r)>,
#   <HDF5 file "data_serial_TIx_50.hdf5" (mode r)>]]

# %%
fssIS, fssISCE = fss[0], fss[1]
for fsIS, fsISCE in zip(fssIS, fssISCE):
    print(fsIS[0]['Primitive/pi11'].shape)
    print(fsISCE[0]['Primitive/p'].shape)
size = fsISCE[0]['Primitive/p'].shape[0]
print(size)
# Out:
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# (4000,)
# 4000

# %%
# eta = fs_IS[0]['Optional'].attrs['eta'][0]
# tau_pi = fs_IS[0]['Optional'].attrs['tau_pi'][0]
# print(f"Dissipation strength {eta}, "
#       f"relaxation time {tau_pi}, "
#       f"timestep {fs_IS[0]['Domain'].attrs['dt'][0]}")

# %%
# eta = fs_ISCE[0]['Optional'].attrs['eta'][0]
# tau_pi = fs_ISCE[0]['Optional'].attrs['tau_pi'][0]
# print(f"Dissipation strength {eta}, "
#       f"relaxation time {tau_pi}, "
#       f"timestep {fs_ISCE[0]['Domain'].attrs['dt'][0]}")

# %%
print("IS: \n")
for fs in fss[0]:
    eta = fs[0]['Optional'].attrs['eta'][0]
    tau_pi = fs[0]['Optional'].attrs['tau_pi'][0]
    print(f"Dissipation strength {eta}, "
          f"relaxation time {tau_pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")

print("ISCE: \n")
for fs in fss[1]:
    eta = fs[0]['Optional'].attrs['eta'][0]
    tau_pi = fs[0]['Optional'].attrs['tau_pi'][0]
    print(f"Dissipation strength {eta}, "
          f"relaxation time {tau_pi}, "
          f"timestep {fs[0]['Domain'].attrs['dt'][0]}")
# Out:
# IS:
#
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.0010000000474974513, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.009999999776482582, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.05000000074505806, relaxation time 0.1, timestep 0.0005
# ISCE:
#
# Dissipation strength 9.999999747378752e-05, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.0010000000474974513, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.009999999776482582, relaxation time 0.1, timestep 0.0005
# Dissipation strength 0.05000000074505806, relaxation time 0.1, timestep 0.0005

# %%
for fs in fss[0]:
    print(fs[-1].attrs['t'])
for fs in fss[1]:
    print(fs[-1].attrs['t'])
# Out:
# [6.]
# [6.]
# [6.]
# [6.]
# [6.]
# [6.]
# [6.]
# [6.]

# %%
#nslice=fs_IS[0]['Domain'].attrs['ny'][0]//2
  
for quant in['D','Tau','S1']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            axis.plot(fs[-1]['Domain/x'], fs[-1]['Conserved/'+quant][:])#,label=rf"$t=${f.attrs['t'][0]:.2e}")
            plt.title(quant)
        #plt.legend()
    plt.savefig("ComparePlots/Cons_"+quant+".pdf")
    plt.show()

# %%
# for quant in['D','Tau','S1']:
#     plt.figure()
#     for n in range(len(fs_IS)):
#         #plt.plot(f['Domain/x'], f['Conserved/'+quant][:,nslice,nslice],label=rf"$t=${f.attrs['t'][0]:.2e}")
#         plt.plot(fs_IS[n]['Domain/x'], (fs_IS[n]['Conserved/'+quant][:] - fs_ISCE[n]['Conserved/'+quant][:])/fs_IS[n]['Conserved/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
#         plt.title(quant)
#     plt.legend()
#     plt.savefig("ComparePlots/ConsRelDiff_"+quant+".pdf")
#     plt.show()

# %%
print("INITIAL DATA")
for quant in['n','rho','p','v1','v2']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            axis.plot(fs[0]['Domain/x'], fs[0]['Primitive/'+quant][:])#=rf"$t=${f.attrs['t'][0]:.2e}")
            plt.title(quant)
    #plt.legend()
    plt.show()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")
# Out:
# INITIAL DATA

# %%
for quant in['n','rho','p','v1','v2']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            axis.plot(fs[-1]['Domain/x'], fs[-1]['Primitive/'+quant][:])
        plt.title(quant)
    #plt.legend()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")

# %%
for quant in ['Pi','q1', 'q2', 'pi11', 'pi12']:
    fig, axes = plt.subplots(1,2)
    axis = axes[0]
    for fsIS in fss_IS:
        for fIS in fsIS:
            axis.plot(fIS['Domain/x'], fIS['Primitive/'+quant][:],label='IS')#=rf"$t=${f.attrs['t'][0]:.2e}")
    axis = axes[1]
    for fsISCE in fss_ISCE:
        for fISCE in fsISCE:
            axis.plot(fISCE['Domain/x'], fISCE['Auxiliary/'+quant+'NS'][:],label='ISCE')#=rf"$t=${f.attrs['t'][0]:.2e}")
    plt.title(quant+' , '+quant+'NS')
    #plt.legend()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")
    plt.show()

# %%
import scipy.special

# %%
for fs_IS, fs_ISCE in zip(fss_IS, fss_ISCE):
    eta = fs_IS[0]['Optional'].attrs['eta'][0]
    print(eta)
    Chi = eta/3.5
    t0 = (1/(72*Chi))
    t1 = t0 + 6
    erf_sol0 = 0.2*scipy.special.erf(fs_IS[0]['Domain/x']/np.sqrt(8*Chi*t0))
    erf_sol1 = 0.2*scipy.special.erf(fs_IS[0]['Domain/x']/np.sqrt(8*Chi*t1))
    plt.figure()
    # plt.plot(fsIS[0]['Domain/x'],erf_sol0,label='erfsol0')
    plt.plot(fsIS[0]['Domain/x'],erf_sol1,label='erfsol1')
    # plt.plot(fss_IS[-1][0]['Domain/x'],fss_IS[-1][0]['Primitive/v2'],label='IS0')
    plt.plot(fs_IS[-1]['Domain/x'],fs_IS[-1]['Primitive/v2'],label='IS1')
    plt.plot(fs_ISCE[-1]['Domain/x'],fs_ISCE[-1]['Primitive/v2'],label='ISCE1')
    plt.legend()
    plt.savefig('finally.pdf')
    plt.show()
# Out:
# 9.999999747378752e-05
# 0.0010000000474974513
# 0.009999999776482582
# 0.05000000074505806

# %%
lims = [0.2,0.8]
for fsIS, fsISCE in zip(fss_IS, fss_ISCE):
    plt.figure()
    fig, axes = plt.subplots(1,3)
    nsl = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
    nsu = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
    eta = fsIS[0]['Optional'].attrs['eta'][0]
    print(eta)
    Chi = eta/3.5
    t0 = (1/(72*Chi))
    t1 = t0 + 6
    erf_sol1 = 0.2*scipy.special.erf(fsIS[0]['Domain/x'][nsl:nsu]/np.sqrt(8*Chi*t1))
    diff_IS = fsIS[-1]['Primitive/v2'][nsl:nsu] - erf_sol1
    diff_ISCE = fsISCE[-1]['Primitive/v2'][nsl:nsu] - erf_sol1
    vmin = min(diff_IS.min(),diff_ISCE.min())
    vmax = max(diff_IS.max(),diff_ISCE.max())
    axes[0].plot(fsIS[0]['Domain/x'][nsl:nsu],erf_sol1,label='erfsol1')
    axes[0].plot(fsIS[-1]['Domain/x'][nsl:nsu],fsIS[-1]['Primitive/v2'][nsl:nsu],label='IS1')
    axes[0].plot(fsISCE[-1]['Domain/x'][nsl:nsu],fsISCE[-1]['Primitive/v2'][nsl:nsu],label='ISCE1')        
    axes[1].plot(fsIS[0]['Domain/x'][nsl:nsu], diff_IS, label=f'{eta:.1g}')
    axes[2].plot(fsIS[0]['Domain/x'][nsl:nsu], diff_ISCE, label=f'{eta:.1g}')
    axes[2].legend()
    axes[0].set_title('v2')
    axes[1].set_title('IS')
    axes[1].set_ylim(1.05*vmin,1.05*vmax)
    axes[2].set_ylim(1.05*vmin,1.05*vmax)
    axes[2].set_title('ISCE')
    plt.tight_layout()
    plt.legend()
    plt.savefig("ComparePlots/DiffAcrossDomain_"+quant+".pdf")
    plt.show()
# Out:
# 9.999999747378752e-05
# 0.0010000000474974513
# 0.009999999776482582
# 0.05000000074505806

# %%
lims = [0.4,0.6]
plt.figure()
for quant in['n','rho','p','v1','v2']:
    fig, axes = plt.subplots(1,2)
    for fsIS, fsISCE in zip(fss_IS, fss_ISCE):
        nsl = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
        nsu = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
        eta = fsIS[0]['Optional'].attrs['eta'][0]
        axes[0].plot(fsIS[0]['Domain/x'][nsl:nsu], fsIS[-1]['Primitive/'+quant][nsl:nsu], label=f'{eta:.1g}')
        axes[0].plot(fsISCE[0]['Domain/x'][nsl:nsu], fsISCE[-1]['Primitive/'+quant][nsl:nsu], label=f'{eta:.1g}')
        axes[1].plot(fsIS[0]['Domain/x'][nsl:nsu], fsIS[-1]['Primitive/'+quant][nsl:nsu] - 
                     fsISCE[-1]['Primitive/'+quant][nsl:nsu], label=f'{eta:.1g}')
        #lt.plot(fsIS[0]['Domain/x'][nsl:nsu], fsIS[-1]['Primitive/'+quant][nsl:nsu] - fsISCE[-1]['Primitive/'+quant][nsl:nsu])
        #plt.plot(fsIS[0]['Domain/x'], fsIS[1]['Primitive/'+quant][:] - fsISCE[1]['Primitive/'+quant][:])
        #plt.title(quant)
        axes[0].legend()
        axes[1].set_title(quant)
    plt.tight_layout()
    plt.legend()
    plt.savefig("ComparePlots/DiffAcrossDomain_"+quant+".pdf")
    plt.show()

# %%
# for quant in['n','rho','p','v1','v2']:
#     plt.figure()
#     #for f in fs:
#     fIS = fs_IS[-1]
#     fISCE = fs_ISCE[-1]
#     plt.plot(fIS['Domain/x'], (fIS['Primitive/'+quant][:] - fISCE['Primitive/'+quant][:])/fIS['Primitive/'+quant][:],label=rf"$t=${f.attrs['t'][0]:.2e}")
#     plt.title(quant)
#     plt.legend()
#     plt.savefig("ComparePlots/PrimsRelDiff_"+quant+".pdf")
#     plt.show()

# %%
for quant in['T','h']:
    fig, axes = plt.subplots(1,2)
    for axis, fssISISCE in zip(axes, fss):
        for fs in fssISISCE:
            eta = fs[0]['Optional'].attrs['eta'][0]
            axis.plot(fs[-1]['Domain/x'], fs[-1]['Auxiliary/'+quant][:],label=f'{eta:.1g}')
        plt.title(quant)
    plt.legend()
    plt.savefig("ComparePlots/Prims_"+quant+".pdf")

# %%
lims=[0.0,1.0]
diffs = []
plt.figure()
for quant in['n','rho','p','v1','v2']:
    for fsIS, fsISCE, size in zip(fss_IS, fss_ISCE, etas):
        nslice_lower = int(lims[0]*fsIS[0]['Primitive/pi11'].shape[0])
        nslice_upper = int(lims[1]*fsIS[0]['Primitive/pi11'].shape[0])
#         diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
#                                    - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),1)/size))
        diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
                                   - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),2)/np.sqrt(size)))
#         diffs.append(np.sum(np.linalg.norm(abs(fsIS[-1]['Primitive/'+quant][nslice_lower:nslice_upper] \
#                                    - fsISCE[-1]['Primitive/'+quant][nslice_lower:nslice_upper]),np.inf)))
    plt.loglog(etas, diffs, 'x')
    slope, intercept = np.polyfit(etas, diffs, 1)
    print(slope, intercept)
    #plt.plot(sizes, intercept + slope*np.array(sizes))
    #plt.plot(sizes, diffs)
    plt.title(quant)
    plt.savefig("ComparePlots/DiffScaling_"+quant+".pdf")
    plt.show()
    diffs.clear()

# for quant in['n','rho','p','v1','v2']:
#     for fsIS, fsISCE, size in zip(fss_IS, fss_ISCE, sizes):
#         print(size, np.sum(np.abs(fsIS[-1]['Primitive/'+quant][:] - fsISCE[-1]['Primitive/'+quant][:])))
#         plt.plot(size, np.sum(np.abs(fsIS[-1]['Primitive/'+quant][:] - fsISCE[-1]['Primitive/'+quant][:])))
#     plt.title(quant)
#     plt.show()
#     #plt.legend()
#     plt.savefig("ComparePlots/Prims_"+quant+".pdf")
# Out:
# 1.083877092588134 0.00966193622004798
# 3.478442722699673 0.030318502579562027
# 1.7179482338230458 0.014285806755137097
# 0.6769954841126008 0.005545368750661153
# 0.1926130511586402 0.030598876577122035
