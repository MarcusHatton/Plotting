# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %%
fs1 = []
fs2 = []
for n in range(11):
  fs1.append(h5py.File('ISCE/KH/Shear/dp_200x200x0_'+str(n)+'.hdf5','r'))
  fs2.append(h5py.File('IS/KH/Shear/dp_200x200x0_'+str(n)+'.hdf5','r'))
fss = [fs1, fs2]

# %%
# fs1 = []
# fs2 = []
# fs3 = []
# for n in range(6):
#   fs1.append(h5py.File('IS/ShearTest/Ideal/data_serial_TIx_'+str(n)+'.hdf5','r'))
#   fs2.append(h5py.File('IS/ShearTest/Shear/data_serial_TIx_'+str(n)+'.hdf5','r'))
#   fs3.append(h5py.File('ISCE/ShearTest/Shear/data_serial_TIx_'+str(n)+'.hdf5','r'))
# fss = [fs1, fs2, fs3]
# fss = [fs1, fs3]

# %%
for fs in fss:
    print('kappa:'+str(fs[0]['Optional'].attrs['kappa']))
for fs in fss:
    print('zeta:'+str(fs[0]['Optional'].attrs['zeta']))
for fs in fss:
    print('eta:'+str(fs[0]['Optional'].attrs['eta']))
# Out:
# kappa:[1.e-15]
# kappa:[1.e-15]
# zeta:[1.e-15]
# zeta:[1.e-15]
# eta:[0.005]
# eta:[0.005]

# %%
# for fs in fss:
#     print(fs[0]['Domain'])

# %%
# for fs in fss:
#     plt.plot(fs[-1]['Domain/x'][:], fs[-1]['Auxiliary/Theta'][:])

# %%
print("INITIAL DATA")
for var in 'p', 'rho', 'n', 'v1', 'v2':
    for fs in fss:
        plt.imshow(fs[0]['Primitive/'+var][:,:])
        plt.colorbar()
        plt.title(var)
        plt.show()
# Out:
# INITIAL DATA

# %%
plt.figure
for fs in fss:
    plt.imshow(fs[-1]['Primitive/v1'][:,:])
    plt.colorbar()
    plt.title('v1')
    plt.show()
    #plt.legend()
plt.savefig('v1.pdf')

# %%
plt.figure
for fs in fss:
    plt.imshow(fs[-1]['Primitive/v2'][:,:])
    plt.colorbar()
    plt.title('v2')
    plt.show()
#plt.legend()
plt.savefig('v2.pdf')

# %%
for var in 'D', 'S1', 'S2', 'Tau':
    for fs in fss:
        plt.imshow(fs[-1]['Conserved/'+var][:])
        plt.title(var)
        #plt.legend()
        plt.savefig(var+'.pdf')
        plt.show()

# %%
for var in 'p', 'rho', 'n':
    for fs in fss:
        plt.imshow(fs[-1]['Primitive/'+var][:])
        plt.title(var)
        #plt.legend()
        plt.savefig(var+'.pdf')
        plt.show()

# %%
for var in 'q1', 'q2', 'Pi', 'pi11', 'pi12', 'pi22':
    for fs in fss:
        plt.imshow(fs[-1]['Auxiliary/'+var+'NS'][:],label=var+'NS')
    plt.title(var)
    plt.colorbar()
    #plt.legend()
    plt.show()
