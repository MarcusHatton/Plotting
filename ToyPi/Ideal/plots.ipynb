# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
# %matplotlib notebook

# %%
f = h5py.File('data_serial.hdf5', 'r')

# %%
f['Domain/x'].shape
# Out:
# (1024,)

# %%
print(f['Primitive/Pi'].shape)
# Out:
# (1024,)

# %%
print(f['Primitive/vx'][:])
# Out:
# [-2.67531566e-57 -3.71405958e-57 -3.85414563e-57 ... -5.93439214e-56
#  -9.56142708e-56 -7.36410823e-56]

# %%
plt.figure()
plt.plot(f['Domain/x'], 7*f['Primitive/vx'][:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Primitive/Pi'][:])
plt.show()
# Out:
# <div id='f3ef31bf-8007-445e-80dc-70ca4ec023f0'></div>

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Auxiliary/Theta'][:])
plt.show()
# Out:
# <div id='c46cd4cb-8c23-456e-ada8-6944f48a9ee9'></div>

# %%
dx = f['Domain/x'][1]-f['Domain/x'][0]
dxT = (f['Primitive/T'][2:, 2] - f['Primitive/T'][:-2,2])/(2*dx)
plt.figure()
plt.plot(f['Domain/x'][1:-1], dxT)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-14cb901a7947> in <module>
#       1 dx = f['Domain/x'][1]-f['Domain/x'][0]
# ----> 2 dxT = (f['Primitive/T'][2:, 2] - f['Primitive/T'][:-2,2])/(2*dx)
#       3 plt.figure()
#       4 plt.plot(f['Domain/x'][1:-1], dxT)
#       5 plt.show()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# D:\Users\marcus\anaconda3\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...
