# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
# %matplotlib notebook

# %%
f = h5py.File('data_serial.hdf5', 'r')
f_id = h5py.File('Ideal/data_serial.hdf5', 'r')

# %%
f['Domain/x'].shape
# Out:
# (1024,)

# %%
print(f['Primitive/Pi'].shape)
# Out:
# (1024,)

# %%
print(f['Primitive/vx'][:])
# Out:
# [4.35402090e-07 4.47554797e-07 4.47638612e-07 ... 4.16072284e-06
#  4.15798623e-06 4.01935159e-06]

# %%
print(f['Auxiliary'].attrs.keys())
print('zeta=gamma=0.01,tau_Pi=sigma=0.001')
# Out:
# <KeysViewHDF5 ['Naux', 'varOrder']>
# zeta=gamma=0.01,tau_Pi=sigma=0.001

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Primitive/vx'][:],label='Non-Ideal')
plt.plot(f['Domain/x'], f_id['Primitive/vx'][:],label='Ideal')
plt.title('Bulk viscous damping of a uniform fluid flow')
plt.xlabel(r'$x$')
plt.ylabel(r'$v_x$')
plt.xlim(0,1)
#plt.vlines(0.7+0.2*0.7+np.sqrt(0.1),0.0,0.7)
#plt.vlines(0.3+0.2*0.7,0.0,0.7)
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('toyPi_uniform_flow_vx.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Primitive/vy'][:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Primitive/Pi'][:],label='Non-Ideal')
plt.plot(f['Domain/x'], f_id['Primitive/Pi'][:],label='Ideal')
plt.xlabel(r'$x$')
plt.ylabel(r'$\Pi$')
plt.xlim(0,1)
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('toyPi_uniform_flow_Pi.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6,6))
ax1.plot(f['Domain/x'], f['Primitive/vx'][:],label='Non-Ideal')
ax1.plot(f['Domain/x'], f_id['Primitive/vx'][:],label='Ideal')
#ax1.set_title('Bulk viscous damping of a uniform fluid flow')
#ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$v_x$')
ax1.set_xticklabels([])
ax1.set_xlim(0,1)
ax1.set_xticks([])
#plt.legend()
#plt.vlines(0.7+0.2*0.7+np.sqrt(0.1),0.0,0.7)
#plt.vlines(0.3+0.2*0.7,0.0,0.7)

ax2.plot(f['Domain/x'], f['Primitive/Pi'][:],label='Non-Ideal')
ax2.plot(f['Domain/x'], f_id['Primitive/Pi'][:],label='Ideal')
ax2.set_xlabel(r'$x$')
ax2.set_ylabel(r'$\Pi$')
ax2.set_xlim(0,1)

plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('toyPi_uniform_flow_both_vert.pdf')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.plot(f['Domain/x'], f['Primitive/vx'][:],label='Non-Ideal')
ax1.plot(f['Domain/x'], f_id['Primitive/vx'][:],label='Ideal')
#plt.title('Bulk viscous damping of a uniform fluid flow')
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$v_x$')
#plt.vlines(0.7+0.2*0.7+np.sqrt(0.1),0.0,0.7)
#plt.vlines(0.3+0.2*0.7,0.0,0.7)

ax2.plot(f['Domain/x'], f['Primitive/Pi'][:],label='Non-Ideal')
ax2.plot(f['Domain/x'], f_id['Primitive/Pi'][:],label='Ideal')
ax2.set_xlabel(r'$x$')
ax2.set_ylabel(r'$\Pi$')

plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('toyPi_uniform_flow_both_vert.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f['Domain/x'], f['Auxiliary/Theta'][:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dx = f['Domain/x'][1]-f['Domain/x'][0]
dxT = (f['Primitive/dvdx'][2:, 2] - f['Primitive/dvdx'][:-2,2])/(2*dx)
plt.figure()
plt.plot(f['Domain/x'][1:-1], dxT)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-b9f4ec6942f6> in <module>
#       1 dx = f['Domain/x'][1]-f['Domain/x'][0]
# ----> 2 dxT = (f['Primitive/dvdx'][2:, 2] - f['Primitive/dvdx'][:-2,2])/(2*dx)
#       3 plt.figure()
#       4 plt.plot(f['Domain/x'][1:-1], dxT)
#       5 plt.show()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# D:\Users\marcus\anaconda3\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...
